# %%
import pandas as pd
import statistics
import numpy as np

# Declaration
data = pd.read_csv("Global Health Statistics.csv")

target_col = ['Prevalence Rate (%)','Incidence Rate (%)','Mortality Rate (%)','Population Affected','Healthcare Access (%)','Doctors per 1000','Hospital Beds per 1000','Average Treatment Cost (USD)',
              'Recovery Rate (%)','DALYs','Improvement in 5 Years (%)','Per Capita Income (USD)','Education Index','Urbanization Rate (%)']

for dt in target_col:
    # Convert to int
    data[dt] = pd.to_numeric(data[dt], errors='coerce')
    
    # Remove NaN
    data = data.dropna(subset=[dt])

    max_val = data[dt].max()
    min_val = data[dt].min()
    range_val = max_val - min_val
    mean = round(data[dt].mean(),2)
    mode = round(statistics.mode(data[dt]),2)
    var = round(np.nanvar(data[dt],ddof=1),2)
    std = round(var ** 0.5,2)

    print(f"Max of {dt.title()} : {max_val}")
    print(f"Min of {dt.title()} : {min_val}")
    print(f"Range of {dt.title()} : {range_val}")
    print(f"Mean of {dt.title()} : {mean}")
    print(f"Mode of {dt.title()} : {mode}")
    print(f"Variance of {dt.title()} : {var}")
    print(f"Standard Deviance of {dt.title()} : {std}\n")
# Out:
# Max of Prevalence Rate (%) : 20.0
# Min of Prevalence Rate (%) : 0.1
# Range of Prevalence Rate (%) : 19.9
# Mean of Prevalence Rate (%) : 10.05
# Mode of Prevalence Rate (%) : 15.87
# Variance of Prevalence Rate (%) : 32.95
# Standard Deviance of Prevalence Rate (%) : 5.74
#
# Max of Incidence Rate (%) : 15.0
# Min of Incidence Rate (%) : 0.1
# Range of Incidence Rate (%) : 14.9
# Mean of Incidence Rate (%) : 7.56
# Mode of Incidence Rate (%) : 5.28
# Variance of Incidence Rate (%) : 18.48
# Standard Deviance of Incidence Rate (%) : 4.3
#
# Max of Mortality Rate (%) : 10.0
# Min of Mortality Rate (%) : 0.1
# Range of Mortality Rate (%) : 9.9
# Mean of Mortality Rate (%) : 5.05
# Mode of Mortality Rate (%) : 6.54
# Variance of Mortality Rate (%) : 8.18
# Standard Deviance of Mortality Rate (%) : 2.86
#
# Max of Population Affected : 1000000
# Min of Population Affected : 1000
# Range of Population Affected : 999000
# Mean of Population Affected : 500735.43
# Mode of Population Affected : 600728
# Variance of Population Affected : 83324662943.15
# Standard Deviance of Population Affected : 288660.12
#
# Max of Healthcare Access (%) : 100.0
# Min of Healthcare Access (%) : 50.0
# Range of Healthcare Access (%) : 50.0
# Mean of Healthcare Access (%) : 74.99
# Mode of Healthcare Access (%) : 59.01
# Variance of Healthcare Access (%) : 208.41
# Standard Deviance of Healthcare Access (%) : 14.44
#
# Max of Doctors Per 1000 : 5.0
# Min of Doctors Per 1000 : 0.5
# Range of Doctors Per 1000 : 4.5
# Mean of Doctors Per 1000 : 2.75
# Mode of Doctors Per 1000 : 2.47
# Variance of Doctors Per 1000 : 1.69
# Standard Deviance of Doctors Per 1000 : 1.3
#
# Max of Hospital Beds Per 1000 : 10.0
# Min of Hospital Beds Per 1000 : 0.5
# Range of Hospital Beds Per 1000 : 9.5
# Mean of Hospital Beds Per 1000 : 5.25
# Mode of Hospital Beds Per 1000 : 7.22
# Variance of Hospital Beds Per 1000 : 7.52
# Standard Deviance of Hospital Beds Per 1000 : 2.74
#
# Max of Average Treatment Cost (Usd) : 50000
# Min of Average Treatment Cost (Usd) : 100
# Range of Average Treatment Cost (Usd) : 49900
# Mean of Average Treatment Cost (Usd) : 25010.31
# Mode of Average Treatment Cost (Usd) : 30847
# Variance of Average Treatment Cost (Usd) : 207425646.94
# Standard Deviance of Average Treatment Cost (Usd) : 14402.28
#
# Max of Recovery Rate (%) : 99.0
# Min of Recovery Rate (%) : 50.0
# Range of Recovery Rate (%) : 49.0
# Mean of Recovery Rate (%) : 74.5
# Mode of Recovery Rate (%) : 60.78
# Variance of Recovery Rate (%) : 200.37
# Standard Deviance of Recovery Rate (%) : 14.16
#
# Max of Dalys : 5000
# Min of Dalys : 1
# Range of Dalys : 4999
# Mean of Dalys : 2499.14
# Mode of Dalys : 4815
# Variance of Dalys : 2084915.93
# Standard Deviance of Dalys : 1443.92
#
# Max of Improvement In 5 Years (%) : 10.0
# Min of Improvement In 5 Years (%) : 0.0
# Range of Improvement In 5 Years (%) : 10.0
# Mean of Improvement In 5 Years (%) : 5.0
# Mode of Improvement In 5 Years (%) : 6.75
# Variance of Improvement In 5 Years (%) : 8.34
# Standard Deviance of Improvement In 5 Years (%) : 2.89
#
# Max of Per Capita Income (Usd) : 100000
# Min of Per Capita Income (Usd) : 500
# Range of Per Capita Income (Usd) : 99500
# Mean of Per Capita Income (Usd) : 50311.1
# Mode of Per Capita Income (Usd) : 99172
# Variance of Per Capita Income (Usd) : 825238194.01
# Standard Deviance of Per Capita Income (Usd) : 28726.96
#
# Max of Education Index : 0.9
# Min of Education Index : 0.4
# Range of Education Index : 0.5
# Mean of Education Index : 0.65
# Mode of Education Index : 0.67
# Variance of Education Index : 0.02
# Standard Deviance of Education Index : 0.14
#
# Max of Urbanization Rate (%) : 90.0
# Min of Urbanization Rate (%) : 20.0
# Range of Urbanization Rate (%) : 70.0
# Mean of Urbanization Rate (%) : 54.99
# Mode of Urbanization Rate (%) : 21.79
# Variance of Urbanization Rate (%) : 408.61
# Standard Deviance of Urbanization Rate (%) : 20.21
